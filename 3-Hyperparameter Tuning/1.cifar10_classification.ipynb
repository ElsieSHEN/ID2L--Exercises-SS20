# %% [markdown]
# # Cifar10 Classification

# %% [markdown]
# Until now, we have implemented several pieces of a deep learning pipeline and even trained a two-layer neural network, but all the hyperparameters were already set to some values yielding resonable results. In real-life problems, however, much of the work in a deep learning project will be geared towards finding the best hyperparameters for a certain problem. In this notebook we will explore some good practices for network debugging and hyperparameters search, as well as extending our previously binary classification neural network to a multi-class one.
#
# Let's go!

# %%
# Some lengthy setup.
import matplotlib.pyplot as plt
import numpy as np
import os

from exercise_code.networks.layer import (
    Sigmoid, 
    Relu, 
    LeakyRelu, 
    Tanh,
)
from exercise_code.data import (
    DataLoader,
    ImageFolderDataset,
    RescaleTransform,
    NormalizeTransform,
    FlattenTransform,
    ComposeTransform,
)
from exercise_code.networks import (
    ClassificationNet,
    BCE,
    CrossEntropyFromLogits
)

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# %% [markdown]
# # 1. Quick recap (and some new things)

# %% [markdown]
# Until now, in the previous exercises, we focused on building and understanding all the necessary modules for training a simple model. We followed the Pytorch implementations closely, as this is the framework we will use later and we want you to have a smoother transition to its APIs.
#
# In the figure below you can see the main components in Pytorch. Before starting the actual exercise, we begin with a quick recap of **our implementation** of these components.
#
# Everything is already implemented for this part, but we **strongly** encourage you to check out the respective source files in order to have a better understanding.

# %% [markdown]
# <img src="https://cdn-images-1.medium.com/max/800/1*uZrS4KjAuSJQIJPgOiaJUg.png" style="width: 500px;">

# %% [markdown]
# ## 1.1 Dataset and Dataloader

# %% [markdown]
# Data preparation represents an important part of deep learning projects. The data comes from different sources and in different formats and is prepared differently from application to application. One part, however, is clear: because entire datasets are usually too large for us to handle at once, we train our models on smaller batches of data.
#
# The goal of the ```Dataset``` class is to encapsulate all the 'dirty' data processing: loading and cleaning the data, storing features (or names of files where features can be found) and labels, as well as providing the means for accessing individual (transformed) items of the data using the ```__getitem__()``` function and an index. You already implemented an ```ImageFolderDataset``` (in ```exercise_code/data/image_folder_dataset.py```) class in Exercise 3. We we will reuse this class here.
#
# For processing the data, you implemented several transforms in Exercise 3 (```RescaleTransform```, ```NormalizeTransform```, ```ComposeTransform```). In this exercise we are working with images, which are multidimensional arrays, but we are using simple feedforward neural network which takes a one dimensional array as an input, so it is necessary to reshape the images before feeding them into the model. We implemented this reshape operation for you in the ```FlattenTransform``` class, also found in ```exercise_code/data/image_folder_dataset.py```.

# %%
download_url = "https://cdn3.vision.in.tum.de/~dl4cv/cifar10.zip"
i2dl_exercises_path = os.path.dirname(os.path.abspath(os.getcwd()))
cifar_root = os.path.join(i2dl_exercises_path, "datasets", "cifar10")

# Use the Cifar10 mean and standard deviation computed in Exercise 3.
cifar_mean = np.array([0.49191375, 0.48235852, 0.44673872])
cifar_std  = np.array([0.24706447, 0.24346213, 0.26147554])

# Define all the transforms we will apply on the images when 
# retrieving them.
rescale_transform = RescaleTransform()
normalize_transform = NormalizeTransform(
    mean=cifar_mean,
    std=cifar_std
)
flatten_transform = FlattenTransform()
compose_transform = ComposeTransform([rescale_transform, 
                                      normalize_transform,
                                      flatten_transform])

# Create a train, validation and test dataset.
datasets = {}
for mode in ['train', 'val', 'test']:
    crt_dataset = ImageFolderDataset(
        mode=mode,
        root=cifar_root, 
        download_url=download_url,
        transform=compose_transform,
        split={'train': 0.6, 'val': 0.2, 'test': 0.2}
    )
    datasets[mode] = crt_dataset
# Out:
# d:\好好学习\2019-2020\TUM\Introduction to Deep Learning\Exercises\datasets\cifar10

# %% [markdown]
# Then, based on this ```Dataset``` object, we can construct a ```Dataloader``` object which samples a random mini-batch of data at once.

# %%
# Create a dataloader for each split.
dataloaders = {}
for mode in ['train', 'val', 'test']:
    crt_dataloader = DataLoader(
        dataset=datasets[mode],
        batch_size=256,
        shuffle=True,
        drop_last=True,
    )
    dataloaders[mode] = crt_dataloader

# %% [markdown]
# Because the ```Dataloader``` has the ```__iter__()``` method, we can simply iterate through the batches it produces, like this:
#
# ```python
# for batch in dataloader['train']:
#     do_something(batch)
# ```

# %% [markdown]
# ## 1.2 Model

# %% [markdown]
# Now, that the data is prepared, we can discuss the model in which we are feeding the data, which in our case will be a neural network.
#
# In Exercise 5, you implemented a simple 2-layer neural network that had a hidden size as a parameter:
#
# $$
# {\hat{y}} = \sigma(\sigma({x W_1} + {b_1}) {W_2} + {b_2})
# $$
#
# where $ \sigma({x}) $ was the sigmoid function, $ {x} $ was the input, $ {W_1}, {W_2} $ the weight matrices and $ {b_1}, {b_2}$ the biases for the two layers.
#
# This is how we used this network:

# %%
input_size = datasets['train'][0]['image'].shape[0]
model = ClassificationNet(input_size=input_size, 
                          hidden_size=512)

# %% [markdown]
# Note that we updated the ```ClassificationNet``` from the previous exercise, so that now you can customize more: the number of outputs, the choice of activation function, the hidden size etc. We encourage you to check out the implementation in ```exercise_code/networks/classification_net.py```

# %%
num_layer = 2
reg = 0.1

model = ClassificationNet(activation=Sigmoid(), 
                          num_layer=num_layer, 
                          reg=reg,
                          num_classes=10)

# %% [markdown]
# Then, the forward and backward passes through the model were simply:
#
# ```python
#
# # X is a batch of training features
# # X.shape = (batch_size, features_size)
# y_out = model.forward(X)
#
# # dout is the gradient of the loss function w.r.t the output of the network.
# # dout.shape = (batch_size, )
# model.backward(dout)
# ```

# %% [markdown]
# Just as the learning rate or the number of iterations we want to train for, the number of hidden layers and the number of units in each hidden layer are also hyperparameters. In this notebook you will play with networks of different sizes and will see the impact that the network capacity has.

# %% [markdown]
# ## 1.3 Loss

# %% [markdown]
# In order to measure how well a network is performing, we implemented several ```Loss``` classes (```L1```, ```MSE```, ```BCE```, each preferred for a certain type of problems) in ```exercise_code/networks/loss.py```.
#
# Each implemented a ```forward()``` method, which outputs a number that we use as a proxy for our network performance.
#
# Also, because our goal was to change the weights of the network such that this loss measure decreases, we were also interested in the gradients of the loss w.r.t the outputs of the network, $ \nabla_{\hat{y}} L({\hat{y}}, {y}) $. This was implemented in ```backward()```.
#
# In previous exercises, we only worked with binary classification and used binary cross entropy (```BCE```) as a loss function.
#
# $$ BCE(\hat{y}, y) = \frac{1}{N} \sum_{i=1}^N \Big [-y_i \log(\hat{y_i}) - (1-y_i) \log(1 - \hat{y_i}) \Big] $$
#
# where
# - $ N $ was the number of samples we were considering
# - $\hat{y}_i$ was the network's prediction for sample $i$. Note that this was a valid probability $\in [0, 1]$, because we applied a [sigmoid](https://en.wikipedia.org/wiki/Sigmoid_function) activation on the last layer.
# - $ y_i $ was the ground truth label (0 or 1, depending on the class)
#
# Because we have 10 classes in the CIFAR10 dataset, we need a generalization of the binary cross entropy for multiple classes. This is simply called the cross entropy loss and has the following definition:
#
# $$ CE(\hat{y}, y) = \frac{1}{N} \sum_{i=1}^N \sum_{k=1}^{C} \Big[ -y_{ik} \log(\hat{y}_{ik}) \Big] $$
#
# where:
# - $ N $ is again the number of samples
# - $ C $ is the number of classes
# - $ \hat{y}_{ik} $ is the probability that the model assigns for the $k$th class when the $i$th sample is the input. **Because we don't apply any activation function on the last layer of our network, its outputs for each sample will not be a valid probability distribution over the classes. We call these raw outputs of the network '[logits](https://datascience.stackexchange.com/questions/31041/what-does-logits-in-machine-learning-mean/31045)' and we will apply a [softmax](https://en.wikipedia.org/wiki/Softmax_function) activation in order to obtain a valid probability distribution.**
# - $y_{ik} = 1 $ iff the true label of the $i$th sample is $k$ and 0 otherwise. This is called a [one-hot encoding](https://machinelearningmastery.com/why-one-hot-encode-data-in-machine-learning/).
#
# You can check for yourself that when the number of classes $ C $ is 2, then the binary cross entropy is actually equivalent to the cross entropy.
#
# We have already implemented the ```CrossEntropyFromLogits``` for you. You can check it out in ```exercise_code/networks/loss.py ```

# %%
loss = CrossEntropyFromLogits()

# %% [markdown]
# Just as with the previous losses we have seen, we can simply get the results of the forward and backward passes as follows:

# %% [markdown]
# ```python
# # y_out is the output of the neural network
# # y_truth is the actual label from the dataset
# loss.forward(y_out, y_truth)
# loss.backward(y_out, y_truth)
# ```

# %% [markdown]
# ## 1.4 Optimizer

# %% [markdown]
# Now, knowing the gradient of the loss w.r.t the ouputs of the network, as well as the local gradient for each layer of the network, we can use the chain rule to compute all gradients.
#
# We implemented several optimizer classes (```SGD```, ```Adam```, ```sgd_momentum```, which you can check out in ```exercise_code/networks/optimizer.py```) that implement different first-order parameter update rules. The ```step()``` method iterates through all the parameters of a model and updates them using the gradient information.
#
# What the optimizer is doing, in pseudocode, is the following:
#
# ```python
# for param in model:
#     # Use the gradient to update the weights.
#     update(param)
#
#     # Reset the gradient after each update.
#     param.gradient = 0
# ```
#
# ```SGD``` had the simplest update rule:
# ```python
# def update(param):
#     param = param - learning_rate * param.gradient
# ```
#
# For the more complicated update rules, see ```exercise_code/networks/optimizer.py```

# %% [markdown]
# ## 1.5 Solver

# %% [markdown]
# The ```Solver``` is where all the above elements come together: given a train and a validation dataloader, a model, a loss and an optimizer, it uses the training data to optimize a model in order to get better predictions. We simply call ```train()``` and it does its 'magic' for us!
# ```python
# solver = Solver(model,
#                 dataloaders['train'],
#                 dataloaders['val'],
#                 learning_rate=0.001,
#                 loss_func=MSE(),
#                 optimizer=SGD)
#
# solver.train(epochs=epochs)
# ```
#
# In order to see, that there is no actual 'magic' check out its implementation in ```exercise_code/solver.py``` ;).

# %% [markdown]
# # 2. An overview of hyperparameters

# %% [markdown]
# <img src=https://images.deepai.org/glossary-terms/05c646fe1676490aa0b8cab0732a02b2/hyperparams.png alt=hyperparameter width=700>
#
# A **hyperparameter** is a parameter that is set before the learning process begins. Recall that the parameters of weight matrix and bias vector are learned during the learning process.
#
# The hyperparameters are essential, for they control and affect the whole training and have a great impact on the performance of the model.
#
# Some examples of hyperparameters we have covered in lectures:
# * Network architecture
#     * Choice of activation function
#     * Number of layers
#     * ...
# * Learning rate
# * Number of epochs
# * Batch size
# * Regularization strength
# * Momentum
# * ...

# %% [markdown]
# ## Start debugging your own network!

# %% [markdown]
# As already suggested in the lectures, you may always want to start from small and simple architectures, to make sure you are going the right way.
#
# First you may need to overfit a single training sample, then a few batches of training samples, then go deeper with larger neural networks and the whole training data.
#
# Here we always provide a default neural network (i.e. ClassificationNet) with arbitrary number of layers, which is a generalization from a fixed 2-layer neural network in exercise 5. You are welcome to implement your own network, in that case just implement **MyOwnNetwork** in ```exercise_code/networks/classification_net.py```. You can also copy things from ClassficationNet and make a little adjustment to your own network. For either way, just pick a network and comment out the other one, then run the cells below for debugging.
#
# __Note__:
# - Please, make sure you don't modify the ClassificationNet itself so that you can always have a working network to fall back on
# - In order to pass this submissions, you can **first stick to the default ClassificationNet implementation without changing any code at all**. The goal of this submission is to find reasonable hyperparameters and the parameter options of the ClassificationNet are broad enough.
# - Once you have surpassed the submission goal, you can try to implement additional activation functions in the accompanying notebook, try different weight initializations or other adjustments by writing your own network architecture in the MyOwnNetwork class.

# %% [markdown]
# First, let's begin with a 2-layer neural network, and overfit one single training sample.
#
# After training, let's evaluate the training process by plotting the loss curves.

# %%
from exercise_code.solver import Solver
from exercise_code.networks.optimizer import SGD, Adam
from exercise_code.networks import MyOwnNetwork

num_layer = 2
epochs = 20
reg = 0.1
batch_size = 4

# model = ClassificationNet(num_layer=num_layer, reg=reg)
model = MyOwnNetwork(num_layer=num_layer, reg=reg)

loss = CrossEntropyFromLogits()

# Make a new data loader with a single training image
overfit_dataset = ImageFolderDataset(
    mode='train',
    root=cifar_root, 
    download_url=download_url,
    transform=compose_transform,
    limit_files=1
)
dataloaders['train_overfit_single_image'] = DataLoader(
    dataset=overfit_dataset,
    batch_size=batch_size,
    shuffle=True,
    drop_last=False,
)

# Decrease validation data for only debugging
debugging_validation_dataset = ImageFolderDataset(
    mode='val',
    root=cifar_root, 
    download_url=download_url,
    transform=compose_transform,
    limit_files=100
)
dataloaders['val_500files'] = DataLoader(
    dataset=debugging_validation_dataset,
    batch_size=batch_size,
    shuffle=True,
    drop_last=True,
)

solver = Solver(model, dataloaders['train_overfit_single_image'], dataloaders['val_500files'], 
                learning_rate=1e-3, loss_func=loss, optimizer=SGD)

solver.train(epochs=epochs)
# Out:
# (Epoch 1 / 20) train loss: 2.333271; val loss: 2.333424
# (Epoch 2 / 20) train loss: 2.333271; val loss: 2.333443
# (Epoch 3 / 20) train loss: 2.332188; val loss: 2.333463
# (Epoch 4 / 20) train loss: 2.331105; val loss: 2.333482
# (Epoch 5 / 20) train loss: 2.330025; val loss: 2.333502
# (Epoch 6 / 20) train loss: 2.328950; val loss: 2.333521
# (Epoch 7 / 20) train loss: 2.327874; val loss: 2.333541
# (Epoch 8 / 20) train loss: 2.326794; val loss: 2.333562
# (Epoch 9 / 20) train loss: 2.325709; val loss: 2.333582
# (Epoch 10 / 20) train loss: 2.324615; val loss: 2.333603
# (Epoch 11 / 20) train loss: 2.323512; val loss: 2.333624
# (Epoch 12 / 20) train loss: 2.322397; val loss: 2.333645
# (Epoch 13 / 20) train loss: 2.321270; val loss: 2.333666
# (Epoch 14 / 20) train loss: 2.320129; val loss: 2.333688
# (Epoch 15 / 20) train loss: 2.318973; val loss: 2.333710
# (Epoch 16 / 20) train loss: 2.317800; val loss: 2.333732
# (Epoch 17 / 20) train loss: 2.316606; val loss: 2.333755
# (Epoch 18 / 20) train loss: 2.315391; val loss: 2.333778
# (Epoch 19 / 20) train loss: 2.314152; val loss: 2.333801
# (Epoch 20 / 20) train loss: 2.312889; val loss: 2.333825

# %%
plt.title('Loss curves')
plt.plot(solver.train_loss_history, '-', label='train')
plt.plot(solver.val_loss_history, '-', label='val')
plt.legend(loc='lower right')
plt.xlabel('Iteration')
plt.show()

# %%
print("Training accuray: %.5f" % (solver.get_dataset_accuracy(dataloaders['train_overfit_single_image'])))
print("Validation accuray: %.5f" % (solver.get_dataset_accuracy(dataloaders['val_500files'])))
# Out:
# Training accuray: 1.00000
# Validation accuray: 0.07000

# %% [markdown]
# This time let's try to overfit to a small set of training batch samples. Please observe the difference from above.

# %%
from exercise_code.networks import MyOwnNetwork

num_layer = 2
epochs = 100
reg = 0.1
num_samples = 10


# model = ClassificationNet(num_layer=num_layer, reg=reg)
model = MyOwnNetwork(num_layer=num_layer, reg=reg)

loss = CrossEntropyFromLogits()

# Make a new data loader with a our num_samples training image
overfit_dataset = ImageFolderDataset(
    mode='train',
    root=cifar_root, 
    download_url=download_url,
    transform=compose_transform,
    limit_files=num_samples
)
dataloaders['train_overfit_10samples'] = DataLoader(
    dataset=overfit_dataset,
    batch_size=batch_size,
    shuffle=True,
    drop_last=False,
)

solver = Solver(model, dataloaders['train_overfit_10samples'], dataloaders['val_500files'], 
                learning_rate=1e-3, loss_func=loss, optimizer=Adam)

solver.train(epochs=epochs)
# Out:
# (Epoch 1 / 100) train loss: 2.330491; val loss: 2.333607
# (Epoch 2 / 100) train loss: 2.325386; val loss: 2.334856
# (Epoch 3 / 100) train loss: 2.208724; val loss: 2.376527
# (Epoch 4 / 100) train loss: 2.082137; val loss: 2.407953
# (Epoch 5 / 100) train loss: 2.080155; val loss: 2.453714
# (Epoch 6 / 100) train loss: 2.004858; val loss: 2.478908
# (Epoch 7 / 100) train loss: 1.969206; val loss: 2.510256
# (Epoch 8 / 100) train loss: 1.884051; val loss: 2.542568
# (Epoch 9 / 100) train loss: 1.919612; val loss: 2.564478
# (Epoch 10 / 100) train loss: 1.941214; val loss: 2.576349
# (Epoch 11 / 100) train loss: 1.902836; val loss: 2.585498
# (Epoch 12 / 100) train loss: 1.850628; val loss: 2.625957
# (Epoch 13 / 100) train loss: 1.841748; val loss: 2.645650
# (Epoch 14 / 100) train loss: 1.902485; val loss: 2.646796
# (Epoch 15 / 100) train loss: 1.831616; val loss: 2.636789
# (Epoch 16 / 100) train loss: 1.860456; val loss: 2.644727
# (Epoch 17 / 100) train loss: 1.915796; val loss: 2.669367
# (Epoch 18 / 100) train loss: 1.846445; val loss: 2.685182
# (Epoch 19 / 100) train loss: 1.984313; val loss: 2.682507
# (Epoch 20 / 100) train loss: 1.830327; val loss: 2.687055
# (Epoch 21 / 100) train loss: 1.816734; val loss: 2.696063
# (Epoch 22 / 100) train loss: 1.914296; val loss: 2.692607
# (Epoch 23 / 100) train loss: 1.893989; val loss: 2.686163
# (Epoch 24 / 100) train loss: 1.799968; val loss: 2.703942
# (Epoch 25 / 100) train loss: 1.833439; val loss: 2.708266
# (Epoch 26 / 100) train loss: 1.965856; val loss: 2.697415
# (Epoch 27 / 100) train loss: 1.807413; val loss: 2.682703
# (Epoch 28 / 100) train loss: 1.821868; val loss: 2.680090
# (Epoch 29 / 100) train loss: 1.961930; val loss: 2.693697
# (Epoch 30 / 100) train loss: 1.824563; val loss: 2.698979
# (Epoch 31 / 100) train loss: 1.883657; val loss: 2.690073
# (Epoch 32 / 100) train loss: 1.883412; val loss: 2.693243
# (Epoch 33 / 100) train loss: 1.811307; val loss: 2.690314
# (Epoch 34 / 100) train loss: 1.808963; val loss: 2.686341
# (Epoch 35 / 100) train loss: 1.807146; val loss: 2.689490
# (Epoch 36 / 100) train loss: 1.799580; val loss: 2.702597
# (Epoch 37 / 100) train loss: 1.799998; val loss: 2.704655
# (Epoch 38 / 100) train loss: 1.866702; val loss: 2.696900
# (Epoch 39 / 100) train loss: 1.798267; val loss: 2.705809
# (Epoch 40 / 100) train loss: 1.812331; val loss: 2.700552
# (Epoch 41 / 100) train loss: 1.872126; val loss: 2.695000
# (Epoch 42 / 100) train loss: 1.803857; val loss: 2.699798
# (Epoch 43 / 100) train loss: 1.810468; val loss: 2.709118
# (Epoch 44 / 100) train loss: 1.870713; val loss: 2.707279
# (Epoch 45 / 100) train loss: 1.867920; val loss: 2.712908
# (Epoch 46 / 100) train loss: 1.862581; val loss: 2.709489
# (Epoch 47 / 100) train loss: 1.780866; val loss: 2.698957
# (Epoch 48 / 100) train loss: 1.860389; val loss: 2.692783
# (Epoch 49 / 100) train loss: 1.789346; val loss: 2.699332
# (Epoch 50 / 100) train loss: 1.784363; val loss: 2.697670
# (Epoch 51 / 100) train loss: 1.808049; val loss: 2.695704
# (Epoch 52 / 100) train loss: 1.862653; val loss: 2.699344
# (Epoch 53 / 100) train loss: 1.860273; val loss: 2.701475
# (Epoch 54 / 100) train loss: 1.860288; val loss: 2.697844
# (Epoch 55 / 100) train loss: 1.804810; val loss: 2.697331
# (Epoch 56 / 100) train loss: 1.866916; val loss: 2.699975
# (Epoch 57 / 100) train loss: 1.776675; val loss: 2.692945
# (Epoch 58 / 100) train loss: 1.851774; val loss: 2.692346
# (Epoch 59 / 100) train loss: 1.846142; val loss: 2.701717
# (Epoch 60 / 100) train loss: 1.776485; val loss: 2.711550
# (Epoch 61 / 100) train loss: 1.776438; val loss: 2.706989
# (Epoch 62 / 100) train loss: 1.838401; val loss: 2.699667
# (Epoch 63 / 100) train loss: 1.783896; val loss: 2.697553
# (Epoch 64 / 100) train loss: 1.779636; val loss: 2.688115
# (Epoch 65 / 100) train loss: 1.776581; val loss: 2.687272
# (Epoch 66 / 100) train loss: 1.768601; val loss: 2.703583
# (Epoch 67 / 100) train loss: 1.831302; val loss: 2.706881
# (Epoch 68 / 100) train loss: 1.805285; val loss: 2.702493
# (Epoch 69 / 100) train loss: 1.781142; val loss: 2.689543
# (Epoch 70 / 100) train loss: 1.846236; val loss: 2.698942
# (Epoch 71 / 100) train loss: 1.838125; val loss: 2.723316
# (Epoch 72 / 100) train loss: 1.831821; val loss: 2.725932
# (Epoch 73 / 100) train loss: 1.797085; val loss: 2.713913
# (Epoch 74 / 100) train loss: 1.773379; val loss: 2.696857
# (Epoch 75 / 100) train loss: 1.768921; val loss: 2.696852
# (Epoch 76 / 100) train loss: 1.763197; val loss: 2.697525
# (Epoch 77 / 100) train loss: 1.771461; val loss: 2.699515
# (Epoch 78 / 100) train loss: 1.769658; val loss: 2.702485
# (Epoch 79 / 100) train loss: 1.752044; val loss: 2.709337
# (Epoch 80 / 100) train loss: 1.735508; val loss: 2.707054
# (Epoch 81 / 100) train loss: 1.807974; val loss: 2.701214
# (Epoch 82 / 100) train loss: 1.811513; val loss: 2.699844
# (Epoch 83 / 100) train loss: 1.811364; val loss: 2.711047
# (Epoch 84 / 100) train loss: 1.764495; val loss: 2.733271
# (Epoch 85 / 100) train loss: 1.826013; val loss: 2.729786
# (Epoch 86 / 100) train loss: 1.781049; val loss: 2.711261
# (Epoch 87 / 100) train loss: 1.761630; val loss: 2.700126
# (Epoch 88 / 100) train loss: 1.804546; val loss: 2.694561
# (Epoch 89 / 100) train loss: 1.752089; val loss: 2.688252
# (Epoch 90 / 100) train loss: 1.747269; val loss: 2.687407
# (Epoch 91 / 100) train loss: 1.747503; val loss: 2.699098
# (Epoch 92 / 100) train loss: 1.763939; val loss: 2.718687
# (Epoch 93 / 100) train loss: 1.795765; val loss: 2.723301
# (Epoch 94 / 100) train loss: 1.752709; val loss: 2.708610
# (Epoch 95 / 100) train loss: 1.794939; val loss: 2.688516
# (Epoch 96 / 100) train loss: 1.804481; val loss: 2.697832
# (Epoch 97 / 100) train loss: 1.784769; val loss: 2.711147
# (Epoch 98 / 100) train loss: 1.745032; val loss: 2.711840
# (Epoch 99 / 100) train loss: 1.721685; val loss: 2.703061
# (Epoch 100 / 100) train loss: 1.783156; val loss: 2.702402

# %%
plt.title('Loss curves')
plt.plot(solver.train_loss_history, '-', label='train')
plt.plot(solver.val_loss_history, '-', label='val')
plt.legend(loc='lower right')
plt.xlabel('Iteration')
plt.show()

# %%
print("Training accuray: %.5f" % (solver.get_dataset_accuracy(dataloaders['train_overfit_10samples'])))
print("Validation accuray: %.5f" % (solver.get_dataset_accuracy(dataloaders['val_500files'])))
# Out:
# Training accuray: 0.30000
# Validation accuray: 0.08000

# %% [markdown]
# If you're overfitting the training data, that means the network's implementation is correct. However, as you have more samples to overfit, your accuracy will be way lower. You can increase the number of epochs above to achieve better results.
#
# Now let's try to feed all the training and validation data into the network, but this time we set the same hyperparameters for 2-layer and 5-layer networks, and compare the different behaviors.
#
# __Note__: This may take about 1 min for each epoch as the training set is quite large. For convenience, we only train on 1000 images for now but use the full validation set.

# %%
from exercise_code.networks import MyOwnNetwork

num_layer = 2
epochs = 5
reg = 0.01

# Make a new data loader with 1000 training samples
num_samples = 1000
overfit_dataset = ImageFolderDataset(
    mode='train',
    root=cifar_root, 
    download_url=download_url,
    transform=compose_transform,
    limit_files=num_samples
)
dataloaders['train_small'] = DataLoader(
    dataset=overfit_dataset,
    batch_size=batch_size,
    shuffle=True,
    drop_last=False,
)


# Change here if you want to use the full training set
use_full_training_set = False
if not use_full_training_set:
    train_loader = dataloaders['train_small']
else:
    train_loader = dataloaders['train']
    

# model = ClassificationNet(num_layer=num_layer, reg=reg)
model = MyOwnNetwork(num_layer=num_layer, reg=reg)

loss = CrossEntropyFromLogits()

solver = Solver(model, train_loader, dataloaders['val'], 
                learning_rate=1e-3, loss_func=loss, optimizer=Adam)

solver.train(epochs=epochs)
# Out:
# (Epoch 1 / 5) train loss: 2.305689; val loss: 2.305695
# (Epoch 2 / 5) train loss: 2.252255; val loss: 2.276929
# (Epoch 3 / 5) train loss: 2.308940; val loss: 2.336136
# (Epoch 4 / 5) train loss: 2.321086; val loss: 2.362163
# (Epoch 5 / 5) train loss: 2.331467; val loss: 2.405390

# %%
plt.title('Loss curves')
plt.plot(solver.train_loss_history, '-', label='train')
plt.plot(solver.val_loss_history, '-', label='val')
plt.legend(loc='lower right')
plt.xlabel('Iteration')
plt.show()

# %%
print("Training accuray: %.5f" % (solver.get_dataset_accuracy(train_loader)))
print("Validation accuray: %.5f" % (solver.get_dataset_accuracy(dataloaders['val'])))
# Out:
# Training accuray: 0.33800
# Validation accuray: 0.26562

# %%
from exercise_code.networks import MyOwnNetwork

num_layer = 5
epochs = 5
reg = 0.01

# model = ClassificationNet(num_layer=num_layer, reg=reg)
model = MyOwnNetwork(num_layer=num_layer, reg=reg)

# Change here if you want to use the full training set
use_full_training_set = False
if not use_full_training_set:
    train_loader = dataloaders['train_small']
else:
    train_loader = dataloaders['train']

loss = CrossEntropyFromLogits()

solver = Solver(model, train_loader, dataloaders['val'], 
                learning_rate=1e-3, loss_func=loss, optimizer=Adam)

solver.train(epochs=epochs)
# Out:
# (Epoch 1 / 5) train loss: 2.305912; val loss: 2.305979
# (Epoch 2 / 5) train loss: 2.327572; val loss: 2.308395
# (Epoch 3 / 5) train loss: 2.318486; val loss: 2.319964
# (Epoch 4 / 5) train loss: 2.313863; val loss: 2.321314
# (Epoch 5 / 5) train loss: 2.317251; val loss: 2.314247

# %%
plt.title('Loss curves')
plt.plot(solver.train_loss_history, '-', label='train')
plt.plot(solver.val_loss_history, '-', label='val')
plt.legend(loc='lower right')
plt.xlabel('Iteration')
plt.show()

# %%
print("Training accuray: %.5f" % (solver.get_dataset_accuracy(train_loader)))
print("Validation accuray: %.5f" % (solver.get_dataset_accuracy(dataloaders['val'])))
# Out:
# Training accuray: 0.10500
# Validation accuray: 0.09826

# %% [markdown]
# As you can see from above, the same hyperparameter set can decrease the loss for a 2-layer network, but for 5-layer network, it hardly works.
#
# The steps above are already mentioned in the lectures as debugging steps before training a neural network.
#
# If you implement your own network, make sure you do the steps above before tuning the hyperparameters as below.

# %% [markdown]
# ## Difficulty in tuning hyperparameters
# As can be seen through the results of training a larger network, training with whole data doesn't fit the training data as well as training with small number of training data. Besides, the architecture of neural network makes a difference, too. Small decisions on hyperparameters count.
#
# Usually, but not always, hyperparameters cannot be learned using well known gradient based methods (such as gradient descent), which are commonly employed to learn parameters. Besides, some hyperparameters can affect the structure of the model and the loss function.
#
# As mentioned before, hyperparameters need to be set before training. Tuning hyperparameters is hard, because you always have to try different combinations of the hyperparameters, train the network, do the validation and pick the best one. Besides, it is not guaranteed that you'll find the best combination.
#
# Next you will do hands on learning with hyperparameter tuning methods that are covered in lectures.

# %% [markdown]
# # Hyperparameter Tuning
#
# ![alt text](https://blog.floydhub.com/content/images/2018/08/Screen-Shot-2018-08-22-at-17.59.25.png "")
#
# One of the main challenges in deep learning is finding the set of hyperparameters that performs best.
#
# So far, we have followed a manual approach by guessing hyperparameters, running the model, observing the result and maybe tweaking the hyperparameters based on this result. As you have probably noticed, this manual hyperparameter tuning is unstructured, inefficient and can become very tedious.
#
#
# A more systematic (and actually very simple) approach for hyperparameter tuning that you've already learned in the lecture  is implementing a **Grid Search**.
#
#
#
# ### Grid Search
# Grid search is a simple and naive, yet effective method to automate the hyperparameter tuning:
#
# * First, you define the set of parameters you want to tune, e.g. $\{learning\_rate, regularization\_strength\}$.
#
# * For each hyperparameter, you then define a set of possible values, e.g. $learning\_rate = \{0.0001, 0.001, 0.01, 0.1\}$.
#
# * Then, you train a model for every possible combination of these hyperparameter values and afterwards select the combination that works best (e.g. in terms of accuracy on your validation set).
#
# Check out our grid search implementation in `exercise_code/hyperparameter_tuning.py`. We show a simple for loop implementation and a more sophisticated one for multiple inputs.
#
# *Note: to keep things simple for the beginning, it'll be enough to just focus on the hyperparameters `learning_rate` and `regularization_strength`
#  here, as in the example above.*

# %%
from exercise_code.networks import MyOwnNetwork

# Specify the used network
# model_class = ClassificationNet
model_class = MyOwnNetwork

from exercise_code import hyperparameter_tuning
best_model, results = hyperparameter_tuning.grid_search(
    dataloaders['train'], dataloaders['val'],
    grid_search_spaces = {
        "learning_rate": [1e-2, 1e-3, 1e-4], 
        "reg": [1e-4]
    },
    model_class=model_class,
    epochs=10, patience=5)
# Out:
# Evaluating Config #1 [of 3]:
#  {'learning_rate': 0.01, 'reg': 0.0001}
# (Epoch 1 / 10) train loss: 2.302628; val loss: 2.302624
# (Epoch 2 / 10) train loss: 2.000679; val loss: 1.901049
# (Epoch 3 / 10) train loss: 1.866753; val loss: 2.014585
# (Epoch 4 / 10) train loss: 1.797809; val loss: 2.029194
# (Epoch 5 / 10) train loss: 1.792210; val loss: 1.876604
# (Epoch 6 / 10) train loss: 1.794974; val loss: 1.922928
# (Epoch 7 / 10) train loss: 1.787267; val loss: 1.961439
# (Epoch 8 / 10) train loss: 1.815937; val loss: 1.970878
# (Epoch 9 / 10) train loss: 1.768573; val loss: 1.926104
# (Epoch 10 / 10) train loss: 1.754514; val loss: 1.931083
# Stopping early at epoch 9!
#
# Evaluating Config #2 [of 3]:
#  {'learning_rate': 0.001, 'reg': 0.0001}
# (Epoch 1 / 10) train loss: 2.302660; val loss: 2.302654
# (Epoch 2 / 10) train loss: 1.818527; val loss: 1.663826
# (Epoch 3 / 10) train loss: 1.570928; val loss: 1.586056
# (Epoch 4 / 10) train loss: 1.476840; val loss: 1.529645
# (Epoch 5 / 10) train loss: 1.403905; val loss: 1.512513
# (Epoch 6 / 10) train loss: 1.352526; val loss: 1.514735
# (Epoch 7 / 10) train loss: 1.309464; val loss: 1.534843
# (Epoch 8 / 10) train loss: 1.270129; val loss: 1.531170
# (Epoch 9 / 10) train loss: 1.236163; val loss: 1.523890
# (Epoch 10 / 10) train loss: 1.195252; val loss: 1.543207
# Stopping early at epoch 9!
#
# Evaluating Config #3 [of 3]:
#  {'learning_rate': 0.0001, 'reg': 0.0001}
# (Epoch 1 / 10) train loss: 2.302638; val loss: 2.302642
# (Epoch 2 / 10) train loss: 2.130329; val loss: 1.974631
# (Epoch 3 / 10) train loss: 1.888592; val loss: 1.843007
# (Epoch 4 / 10) train loss: 1.789474; val loss: 1.773038
# (Epoch 5 / 10) train loss: 1.725501; val loss: 1.722782
# (Epoch 6 / 10) train loss: 1.675570; val loss: 1.684786
# (Epoch 7 / 10) train loss: 1.634817; val loss: 1.652402
# (Epoch 8 / 10) train loss: 1.600954; val loss: 1.630835
# (Epoch 9 / 10) train loss: 1.572157; val loss: 1.609199
# (Epoch 10 / 10) train loss: 1.546766; val loss: 1.593937
#
# Search done. Best Val Loss = 1.5125127475624556
# Best Config: {'learning_rate': 0.001, 'reg': 0.0001}

# %% [markdown]
# From the results of your grid search, you might already have found some hyperparameter combinations that work better than others. A common practice is to now repeat the grid search on a more narrow domain centered around the parameters that worked best.
#
# **Conclusion Grid Search**
#
# With grid search we now have automated the hyperparameter tuning to a certain degree. Another advantage is, that since the training of all models are independent of each other, you can parallelize the grid search, i.e.,  try out different hyperparameter configurations in parallel on different machines.
#
# However, as you have probably noticed, there is one big problem with this approach: the number of possible combinations to try out grows exponentially with the number of hyperparameters ("curse of dimensionality"). As we add more hyperparameters to the grid search, the search space will explode in time complexity, making this strategy unfeasible.

# %% [markdown]
# Especially when your search space contains more than 3 or 4 dimensions, it is often better to use another, similar hyperparameter tuning method that you've already learned about: random search.

# %% [markdown]
# ## Random Search
# Random search is very similar to grid search, with the only difference, that instead of providing specific values for every hyperparameter, you only define a range for each hyperparameter - then, the values are sampled randomly from the provided ranges.
#
# ![alt text](https://i.stack.imgur.com/cIDuR.png "")
#
# The figure above illustrates the difference in the hyperparameter space exploration between grid search and random search: assume you have 2 hyperparameters with each 3 values. Running a grid search results in training $3^2=9$ different models - but in the end, you've just tired out 3 values for each parameter. For random search on the other hand, after training 9 models you'll have tried out 9 different values for each hyperparameter, which often leads much faster to good results.
#
# To get a deeper understanding of random search and why it is more efficient than grid search, you should definitely check out this paper: http://www.jmlr.org/papers/volume13/bergstra12a/bergstra12a.pdf
#
#
#
#
# Now please implement the `nn_random_search` function in `exercise_code/networks/hyperparameter_tuning.py`.
#
# *Hint: regarding the sample space of each parameter, think about the scale for which it makes most sense to sample in. For example the learning rate is usually sampled on a logarithmic scale!*
#
# *For simplicity and speed, just use the `train_batches`-dataloader!*

# %%
from exercise_code.hyperparameter_tuning import random_search
from exercise_code.networks import MyOwnNetwork

# Specify the used network
model_class = ClassificationNet

best_model, results = random_search(
    dataloaders['train_small'], dataloaders['val_500files'],
    random_search_spaces = {
        "learning_rate": ([1e-2, 1e-6], 'log'),
        "reg": ([1e-3, 1e-7], "log"),
        "loss_func": ([CrossEntropyFromLogits()], "item")
    },
    model_class=model_class,
    num_search = 1, epochs=20, patience=5)
# Out:
# Evaluating Config #1 [of 10]:
#  {'learning_rate': 0.00045987881381349017, 'reg': 3.5803774264036787e-06, 'loss_func': <exercise_code.networks.loss.CrossEntropyFromLogits object at 0x000001EF198EAA90>, 'activation': <exercise_code.networks.layer.LeakyRelu object at 0x000001EF198EAC50>}
# (Epoch 1 / 20) train loss: 2.302558; val loss: 2.302560
# (Epoch 2 / 20) train loss: 1.908160; val loss: 1.737772
# (Epoch 3 / 20) train loss: 1.650351; val loss: 1.631619
# (Epoch 4 / 20) train loss: 1.547702; val loss: 1.576866
# (Epoch 5 / 20) train loss: 1.482681; val loss: 1.554706
# (Epoch 6 / 20) train loss: 1.430657; val loss: 1.520597
# (Epoch 7 / 20) train loss: 1.384383; val loss: 1.504558
# (Epoch 8 / 20) train loss: 1.343863; val loss: 1.498113
# (Epoch 9 / 20) train loss: 1.308312; val loss: 1.495876
# (Epoch 10 / 20) train loss: 1.273896; val loss: 1.474017
# (Epoch 11 / 20) train loss: 1.239385; val loss: 1.468247
# (Epoch 12 / 20) train loss: 1.210926; val loss: 1.473861
# (Epoch 13 / 20) train loss: 1.183579; val loss: 1.469830
# (Epoch 14 / 20) train loss: 1.155515; val loss: 1.474418
# (Epoch 15 / 20) train loss: 1.124635; val loss: 1.471466
# (Epoch 16 / 20) train loss: 1.104847; val loss: 1.475776
# Stopping early at epoch 15!
#
# Evaluating Config #2 [of 10]:
#  {'learning_rate': 0.00022393057131881052, 'reg': 1.3566720603112278e-06, 'loss_func': <exercise_code.networks.loss.CrossEntropyFromLogits object at 0x000001EF198EAA90>, 'activation': <exercise_code.networks.layer.LeakyRelu object at 0x000001EF198EAC50>}
# (Epoch 1 / 20) train loss: 2.302572; val loss: 2.302568
# (Epoch 2 / 20) train loss: 2.001946; val loss: 1.833475
# (Epoch 3 / 20) train loss: 1.749069; val loss: 1.714047
# (Epoch 4 / 20) train loss: 1.648501; val loss: 1.640623
# (Epoch 5 / 20) train loss: 1.582038; val loss: 1.602552
# (Epoch 6 / 20) train loss: 1.531220; val loss: 1.571619
# (Epoch 7 / 20) train loss: 1.491883; val loss: 1.548546
# (Epoch 8 / 20) train loss: 1.457389; val loss: 1.533638
# (Epoch 9 / 20) train loss: 1.427182; val loss: 1.516150
# (Epoch 10 / 20) train loss: 1.399568; val loss: 1.500956
# (Epoch 11 / 20) train loss: 1.370173; val loss: 1.493735
# (Epoch 12 / 20) train loss: 1.345963; val loss: 1.491632
# (Epoch 13 / 20) train loss: 1.324993; val loss: 1.481219
# (Epoch 14 / 20) train loss: 1.302531; val loss: 1.473328
# (Epoch 15 / 20) train loss: 1.283659; val loss: 1.466374
# (Epoch 16 / 20) train loss: 1.264452; val loss: 1.460983
# (Epoch 17 / 20) train loss: 1.245520; val loss: 1.461263
# (Epoch 18 / 20) train loss: 1.228165; val loss: 1.458127
# (Epoch 19 / 20) train loss: 1.211331; val loss: 1.452221
# (Epoch 20 / 20) train loss: 1.195003; val loss: 1.455621
#
# Evaluating Config #3 [of 10]:
#  {'learning_rate': 0.00047968839719825495, 'reg': 8.404712945366124e-07, 'loss_func': <exercise_code.networks.loss.CrossEntropyFromLogits object at 0x000001EF198EAA90>, 'activation': <exercise_code.networks.layer.LeakyRelu object at 0x000001EF198EAC50>}
# (Epoch 1 / 20) train loss: 2.302529; val loss: 2.302532
# (Epoch 2 / 20) train loss: 1.909036; val loss: 1.740171
# (Epoch 3 / 20) train loss: 1.653919; val loss: 1.625303
# (Epoch 4 / 20) train loss: 1.542260; val loss: 1.575980
# (Epoch 5 / 20) train loss: 1.473852; val loss: 1.528054
# (Epoch 6 / 20) train loss: 1.421773; val loss: 1.519247
# (Epoch 7 / 20) train loss: 1.374622; val loss: 1.509316
# (Epoch 8 / 20) train loss: 1.334365; val loss: 1.487480
# (Epoch 9 / 20) train loss: 1.294665; val loss: 1.481184
# (Epoch 10 / 20) train loss: 1.263742; val loss: 1.472637
# (Epoch 11 / 20) train loss: 1.228963; val loss: 1.479081
# (Epoch 12 / 20) train loss: 1.200268; val loss: 1.480309
# (Epoch 13 / 20) train loss: 1.174650; val loss: 1.489514
# (Epoch 14 / 20) train loss: 1.143443; val loss: 1.483953
# (Epoch 15 / 20) train loss: 1.121737; val loss: 1.486850
# Stopping early at epoch 14!
#
# Evaluating Config #4 [of 10]:
#  {'learning_rate': 0.0004905934030389003, 'reg': 5.863154854964322e-06, 'loss_func': <exercise_code.networks.loss.CrossEntropyFromLogits object at 0x000001EF198EAA90>, 'activation': <exercise_code.networks.layer.LeakyRelu object at 0x000001EF198EAC50>}
# (Epoch 1 / 20) train loss: 2.302610; val loss: 2.302611
# (Epoch 2 / 20) train loss: 1.903799; val loss: 1.732197
# (Epoch 3 / 20) train loss: 1.639377; val loss: 1.615152
# (Epoch 4 / 20) train loss: 1.537271; val loss: 1.559816
# (Epoch 5 / 20) train loss: 1.466063; val loss: 1.532196
# (Epoch 6 / 20) train loss: 1.412482; val loss: 1.501722
# (Epoch 7 / 20) train loss: 1.364050; val loss: 1.489586
# (Epoch 8 / 20) train loss: 1.324504; val loss: 1.478911
# (Epoch 9 / 20) train loss: 1.286077; val loss: 1.467891
# (Epoch 10 / 20) train loss: 1.250870; val loss: 1.460323
# (Epoch 11 / 20) train loss: 1.218578; val loss: 1.457990
# (Epoch 12 / 20) train loss: 1.193649; val loss: 1.450126
# (Epoch 13 / 20) train loss: 1.160887; val loss: 1.464589
# (Epoch 14 / 20) train loss: 1.134223; val loss: 1.462093
# (Epoch 15 / 20) train loss: 1.108731; val loss: 1.466168
# (Epoch 16 / 20) train loss: 1.085197; val loss: 1.470027
# (Epoch 17 / 20) train loss: 1.064949; val loss: 1.483812
# Stopping early at epoch 16!
#
# Evaluating Config #5 [of 10]:
#  {'learning_rate': 0.00017117271019699906, 'reg': 7.445345245584399e-06, 'loss_func': <exercise_code.networks.loss.CrossEntropyFromLogits object at 0x000001EF198EAA90>, 'activation': <exercise_code.networks.layer.LeakyRelu object at 0x000001EF198EAC50>}
# (Epoch 1 / 20) train loss: 2.302646; val loss: 2.302647
# (Epoch 2 / 20) train loss: 2.048065; val loss: 1.879442
# (Epoch 3 / 20) train loss: 1.794548; val loss: 1.756814
# (Epoch 4 / 20) train loss: 1.696696; val loss: 1.684233
# (Epoch 5 / 20) train loss: 1.629999; val loss: 1.639628
# (Epoch 6 / 20) train loss: 1.576924; val loss: 1.603866
# (Epoch 7 / 20) train loss: 1.536385; val loss: 1.581884
# (Epoch 8 / 20) train loss: 1.502516; val loss: 1.559295
# (Epoch 9 / 20) train loss: 1.472889; val loss: 1.543832
# (Epoch 10 / 20) train loss: 1.447013; val loss: 1.533473
# (Epoch 11 / 20) train loss: 1.423202; val loss: 1.516243
# (Epoch 12 / 20) train loss: 1.399328; val loss: 1.509501
# (Epoch 13 / 20) train loss: 1.379449; val loss: 1.499885
# (Epoch 14 / 20) train loss: 1.359367; val loss: 1.492999
# (Epoch 15 / 20) train loss: 1.341111; val loss: 1.488822
# (Epoch 16 / 20) train loss: 1.323938; val loss: 1.479307
# (Epoch 17 / 20) train loss: 1.306107; val loss: 1.475507
# (Epoch 18 / 20) train loss: 1.289564; val loss: 1.471653
# (Epoch 19 / 20) train loss: 1.273855; val loss: 1.465364
# (Epoch 20 / 20) train loss: 1.258484; val loss: 1.461374
#
# Evaluating Config #6 [of 10]:
#  {'learning_rate': 0.00046276288967975074, 'reg': 6.284707608856258e-06, 'loss_func': <exercise_code.networks.loss.CrossEntropyFromLogits object at 0x000001EF198EAA90>, 'activation': <exercise_code.networks.layer.LeakyRelu object at 0x000001EF198EAC50>}
# (Epoch 1 / 20) train loss: 2.302630; val loss: 2.302634
# (Epoch 2 / 20) train loss: 1.903818; val loss: 1.734112
# (Epoch 3 / 20) train loss: 1.648366; val loss: 1.627564
# (Epoch 4 / 20) train loss: 1.544653; val loss: 1.575329
# (Epoch 5 / 20) train loss: 1.478066; val loss: 1.536423
# (Epoch 6 / 20) train loss: 1.424437; val loss: 1.516726
# (Epoch 7 / 20) train loss: 1.378548; val loss: 1.492120
# (Epoch 8 / 20) train loss: 1.337512; val loss: 1.481363
# (Epoch 9 / 20) train loss: 1.300754; val loss: 1.486706
# (Epoch 10 / 20) train loss: 1.267305; val loss: 1.473657
# (Epoch 11 / 20) train loss: 1.239234; val loss: 1.479442
# (Epoch 12 / 20) train loss: 1.207226; val loss: 1.463445
# (Epoch 13 / 20) train loss: 1.177526; val loss: 1.468745
# (Epoch 14 / 20) train loss: 1.154010; val loss: 1.476619
# (Epoch 15 / 20) train loss: 1.125148; val loss: 1.472374
# (Epoch 16 / 20) train loss: 1.101568; val loss: 1.476951
# (Epoch 17 / 20) train loss: 1.075877; val loss: 1.482403
# Stopping early at epoch 16!
#
# Evaluating Config #7 [of 10]:
#  {'learning_rate': 0.0003705482628897895, 'reg': 3.1066093270947268e-06, 'loss_func': <exercise_code.networks.loss.CrossEntropyFromLogits object at 0x000001EF198EAA90>, 'activation': <exercise_code.networks.layer.LeakyRelu object at 0x000001EF198EAC50>}
# (Epoch 1 / 20) train loss: 2.302574; val loss: 2.302573
# (Epoch 2 / 20) train loss: 1.928865; val loss: 1.760466
# (Epoch 3 / 20) train loss: 1.673720; val loss: 1.642630
# (Epoch 4 / 20) train loss: 1.572520; val loss: 1.585815
# (Epoch 5 / 20) train loss: 1.509296; val loss: 1.562569
# (Epoch 6 / 20) train loss: 1.457655; val loss: 1.535206
# (Epoch 7 / 20) train loss: 1.415433; val loss: 1.512640
# (Epoch 8 / 20) train loss: 1.377600; val loss: 1.499964
# (Epoch 9 / 20) train loss: 1.343949; val loss: 1.492765
# (Epoch 10 / 20) train loss: 1.307792; val loss: 1.485446
# (Epoch 11 / 20) train loss: 1.279940; val loss: 1.478354
# (Epoch 12 / 20) train loss: 1.253199; val loss: 1.472675
# (Epoch 13 / 20) train loss: 1.229470; val loss: 1.474457
# (Epoch 14 / 20) train loss: 1.201746; val loss: 1.476692
# (Epoch 15 / 20) train loss: 1.176709; val loss: 1.477025
# (Epoch 16 / 20) train loss: 1.153240; val loss: 1.482798
# (Epoch 17 / 20) train loss: 1.133563; val loss: 1.477655
# Stopping early at epoch 16!
#
# Evaluating Config #8 [of 10]:
#  {'learning_rate': 0.00033653015546604144, 'reg': 8.411039720344441e-06, 'loss_func': <exercise_code.networks.loss.CrossEntropyFromLogits object at 0x000001EF198EAA90>, 'activation': <exercise_code.networks.layer.LeakyRelu object at 0x000001EF198EAC50>}
# (Epoch 1 / 20) train loss: 2.302578; val loss: 2.302575
# (Epoch 2 / 20) train loss: 1.947146; val loss: 1.774036
# (Epoch 3 / 20) train loss: 1.692644; val loss: 1.661601
# (Epoch 4 / 20) train loss: 1.591590; val loss: 1.606980
# (Epoch 5 / 20) train loss: 1.525655; val loss: 1.559944
# (Epoch 6 / 20) train loss: 1.471357; val loss: 1.544732
# (Epoch 7 / 20) train loss: 1.431339; val loss: 1.518877
# (Epoch 8 / 20) train loss: 1.392501; val loss: 1.501544
# (Epoch 9 / 20) train loss: 1.357840; val loss: 1.490783
# (Epoch 10 / 20) train loss: 1.325570; val loss: 1.480127
# (Epoch 11 / 20) train loss: 1.294283; val loss: 1.479097
# (Epoch 12 / 20) train loss: 1.269120; val loss: 1.465238
# (Epoch 13 / 20) train loss: 1.244221; val loss: 1.469760
# (Epoch 14 / 20) train loss: 1.217195; val loss: 1.461652
# (Epoch 15 / 20) train loss: 1.196627; val loss: 1.463341
# (Epoch 16 / 20) train loss: 1.170186; val loss: 1.463242
# (Epoch 17 / 20) train loss: 1.150395; val loss: 1.464687
# (Epoch 18 / 20) train loss: 1.130336; val loss: 1.466064
# (Epoch 19 / 20) train loss: 1.109567; val loss: 1.471448
# Stopping early at epoch 18!
#
# Evaluating Config #9 [of 10]:
#  {'learning_rate': 0.00020246040733641743, 'reg': 1.990313199045935e-06, 'loss_func': <exercise_code.networks.loss.CrossEntropyFromLogits object at 0x000001EF198EAA90>, 'activation': <exercise_code.networks.layer.LeakyRelu object at 0x000001EF198EAC50>}
# (Epoch 1 / 20) train loss: 2.302575; val loss: 2.302575
# (Epoch 2 / 20) train loss: 2.022960; val loss: 1.858052
# (Epoch 3 / 20) train loss: 1.773541; val loss: 1.732731
# (Epoch 4 / 20) train loss: 1.671788; val loss: 1.663967
# (Epoch 5 / 20) train loss: 1.603296; val loss: 1.621681
# (Epoch 6 / 20) train loss: 1.551531; val loss: 1.586005
# (Epoch 7 / 20) train loss: 1.511232; val loss: 1.560434
# (Epoch 8 / 20) train loss: 1.477489; val loss: 1.544550
# (Epoch 9 / 20) train loss: 1.447896; val loss: 1.526909
# (Epoch 10 / 20) train loss: 1.419743; val loss: 1.516660
# (Epoch 11 / 20) train loss: 1.395776; val loss: 1.505676
# (Epoch 12 / 20) train loss: 1.374572; val loss: 1.494039
# (Epoch 13 / 20) train loss: 1.350808; val loss: 1.484491
# (Epoch 14 / 20) train loss: 1.329221; val loss: 1.482895
# (Epoch 15 / 20) train loss: 1.310255; val loss: 1.475910
# (Epoch 16 / 20) train loss: 1.291526; val loss: 1.471510
# (Epoch 17 / 20) train loss: 1.272297; val loss: 1.464062
# (Epoch 18 / 20) train loss: 1.254818; val loss: 1.463380
# (Epoch 19 / 20) train loss: 1.237660; val loss: 1.457623
# (Epoch 20 / 20) train loss: 1.220724; val loss: 1.454810
#
# Evaluating Config #10 [of 10]:
#  {'learning_rate': 0.0003653891281201983, 'reg': 3.1147748204005135e-06, 'loss_func': <exercise_code.networks.loss.CrossEntropyFromLogits object at 0x000001EF198EAA90>, 'activation': <exercise_code.networks.layer.LeakyRelu object at 0x000001EF198EAC50>}
# (Epoch 1 / 20) train loss: 2.302560; val loss: 2.302563
# (Epoch 2 / 20) train loss: 1.933744; val loss: 1.768687
# (Epoch 3 / 20) train loss: 1.685314; val loss: 1.657979
# (Epoch 4 / 20) train loss: 1.582236; val loss: 1.592897
# (Epoch 5 / 20) train loss: 1.512357; val loss: 1.555344
# (Epoch 6 / 20) train loss: 1.459723; val loss: 1.536468
# (Epoch 7 / 20) train loss: 1.416217; val loss: 1.515092
# (Epoch 8 / 20) train loss: 1.377260; val loss: 1.493504
# (Epoch 9 / 20) train loss: 1.343520; val loss: 1.481318
# (Epoch 10 / 20) train loss: 1.308416; val loss: 1.473908
# (Epoch 11 / 20) train loss: 1.278747; val loss: 1.471437
# (Epoch 12 / 20) train loss: 1.250067; val loss: 1.463304
# (Epoch 13 / 20) train loss: 1.225412; val loss: 1.455461
# (Epoch 14 / 20) train loss: 1.197370; val loss: 1.456748
# (Epoch 15 / 20) train loss: 1.173851; val loss: 1.468728
# (Epoch 16 / 20) train loss: 1.154284; val loss: 1.455886
# (Epoch 17 / 20) train loss: 1.130801; val loss: 1.463328
# (Epoch 18 / 20) train loss: 1.107255; val loss: 1.471629
# Stopping early at epoch 17!
#
# Search done. Best Val Loss = 1.4501263304279255
# Best Config: {'learning_rate': 0.0004905934030389003, 'reg': 5.863154854964322e-06, 'loss_func': <exercise_code.networks.loss.CrossEntropyFromLogits object at 0x000001EF198EAA90>, 'activation': <exercise_code.networks.layer.LeakyRelu object at 0x000001EF198EAC50>}

# %% [markdown]
# Search done. Best Val Loss = 1.4864400446180381
# Best Config: {'learning_rate': 0.0003570765010665611, 'reg': 0.0001701247624977143, 'loss_func': <exercise_code.networks.loss.CrossEntropyFromLogits object at 0x000001EF15DB1A20>, 'activation': <exercise_code.networks.layer.LeakyRelu object at 0x000001EF198D7F98>}
#
# Search done. Best Val Loss = 1.4549238368896205
# Best Config: {'learning_rate': 0.00026246019303088495, 'reg': 9.695368906095447e-05, 'loss_func': <exercise_code.networks.loss.CrossEntropyFromLogits object at 0x000001EF1999B518>, 'activation': <exercise_code.networks.layer.LeakyRelu object at 0x000001EF15DBA898>}
#
# Search done. Best Val Loss = 1.4661283066919428
# Best Config: {'learning_rate': 0.00027524636274661263, 'reg': 6.685989560330436e-05, 'loss_func': <exercise_code.networks.loss.CrossEntropyFromLogits object at 0x000001EF15DBA5F8>, 'activation': <exercise_code.networks.layer.LeakyRelu object at 0x000001EF15DBA208>}
#
# Search done. Best Val Loss = 1.4501263304279255
# Best Config: {'learning_rate': 0.0004905934030389003, 'reg': 5.863154854964322e-06, 'loss_func': <exercise_code.networks.loss.CrossEntropyFromLogits object at 0x000001EF198EAA90>, 'activation': <exercise_code.networks.layer.LeakyRelu object at 0x000001EF198EAC50>}

# %% [markdown]
# If your implementation works, then it's time to run it with the whole dataset, and let it search for a few hours for a nice configuration.
#
# However, to save some time, let's first implement an **early-stopping** mechanism, that you also already know from the lecture.

# %% [markdown]
# ## Early Stopping

# %% [markdown]
# By now you've already seen a lot of training curves:
#
# <img src=http://fouryears.eu/wp-content/uploads/2017/12/early_stopping.png></img>
#
# Usually, at some point the validation loss goes up again, which is a sign that we're overfitting to our training data. Since it actually doesn't make any sense to train further at this point, it's common practice to apply "early stopping", i.e., cancel the training process when the validation loss doesn't improve anymore. The nice thing about this concept is, that not only it improves generalization through the prevention of overfitting, but also it saves us a lot of time - one of our most valuable resources in deep learning.
#
# Since there are natural fluctuations in the validation loss, you usually don't cancel the training process right at the first epoch when the validation-loss increases, but instead, you wait for some epochs (specified by the `patience`-parameter) and if the loss still doesn't improve, we stop.
#
# Now, take a look at the implement of early stopping mechanism in the `solver.py` file.

# %% [markdown]
# ## Let's find the perfect model!

# %% [markdown]
# You've now set everything up to start training your model and finding a nice set of hyper parameters using a combination of grid or random search!
#
# Since we'll now be training with a much larger number of samples, you should be aware that this process will definitely take some time! So be prepared to let your machine run for a while.
#
# At the beginning, it's a good approach to first do a coarse random search across a wide range of values to find promising sub-ranges of your parameter space. Afterwards, you can zoom in to these ranges and do another random search (or grid search) to finetune the configuration.
#
# You don't have to use the whole dataset at the beginning, instead you can also use a medium large subset of the samples. Also, you don't need to train for a large number of epochs - as mentioned above: we first want to get an overview about our hyper parameters.
#
# **Task: put in some reasonable ranges for the hyperparameters and evaluate them using random search!**
#
# Finally, once you've found some good hyper parameters, train on the whole dataset for a large number of epochs and make sure you use the full training data!

# %%
num_layer = 5
reg = 1e-6
epochs = 20

# best_model = ClassificationNet(num_layer=num_layer, reg=reg)
best_model = MyOwnNetwork(num_layer=num_layer, reg=reg)

########################################################################
# TODO:                                                                #
# Implement your own neural network and find suitable hyperparameters  #
# Be sure to edit the MyOwnNetwork class in the following code snippet #
# to upload the correct model!                                         #
########################################################################

from exercise_code.hyperparameter_tuning import random_search
from exercise_code.networks import MyOwnNetwork

# Specify the used network
# model_class = ClassificationNet
model_class = MyOwnNetwork

best_model, results = random_search(
    dataloaders['train'], dataloaders['val'],
    random_search_spaces = {
        "learning_rate": ([1e-3, 5e-4], 'float'),
        "reg": ([1e-5, 1e-8], "float"),
        "loss_func": ([CrossEntropyFromLogits()], "item"),
        "activation": ([LeakyRelu()], "item")
    },
    model_class=model_class,
    num_search = 10, epochs=20, patience=5)

########################################################################
#                           END OF YOUR CODE                           #
########################################################################
# Out:
# Evaluating Config #1 [of 10]:
#  {'learning_rate': 0.0005566921237071903, 'reg': 6.891715848497006e-06, 'loss_func': <exercise_code.networks.loss.CrossEntropyFromLogits object at 0x000001EF198D74E0>, 'activation': <exercise_code.networks.layer.LeakyRelu object at 0x000001EF199BC7B8>}
# (Epoch 1 / 20) train loss: 2.302574; val loss: 2.302579
# (Epoch 2 / 20) train loss: 1.877545; val loss: 1.714727
# (Epoch 3 / 20) train loss: 1.628728; val loss: 1.620576
# (Epoch 4 / 20) train loss: 1.526170; val loss: 1.555846
# (Epoch 5 / 20) train loss: 1.455244; val loss: 1.533845
# (Epoch 6 / 20) train loss: 1.401620; val loss: 1.503050
# (Epoch 7 / 20) train loss: 1.353014; val loss: 1.487659
# (Epoch 8 / 20) train loss: 1.312589; val loss: 1.478080
# (Epoch 9 / 20) train loss: 1.273760; val loss: 1.487561
# (Epoch 10 / 20) train loss: 1.239948; val loss: 1.476302
# (Epoch 11 / 20) train loss: 1.202782; val loss: 1.460793
# (Epoch 12 / 20) train loss: 1.174311; val loss: 1.472406
# (Epoch 13 / 20) train loss: 1.147332; val loss: 1.474621
# (Epoch 14 / 20) train loss: 1.114261; val loss: 1.479829
# (Epoch 15 / 20) train loss: 1.089298; val loss: 1.491247
# (Epoch 16 / 20) train loss: 1.059613; val loss: 1.502005
# Stopping early at epoch 15!
#
# Evaluating Config #2 [of 10]:
#  {'learning_rate': 0.0006929887019080978, 'reg': 9.831611448390105e-06, 'loss_func': <exercise_code.networks.loss.CrossEntropyFromLogits object at 0x000001EF198D74E0>, 'activation': <exercise_code.networks.layer.LeakyRelu object at 0x000001EF199BC7B8>}
# (Epoch 1 / 20) train loss: 2.302595; val loss: 2.302592
# (Epoch 2 / 20) train loss: 1.850013; val loss: 1.678337
# (Epoch 3 / 20) train loss: 1.597256; val loss: 1.582079
# (Epoch 4 / 20) train loss: 1.495375; val loss: 1.547283
# (Epoch 5 / 20) train loss: 1.428826; val loss: 1.521457
# (Epoch 6 / 20) train loss: 1.372210; val loss: 1.496348
# (Epoch 7 / 20) train loss: 1.326777; val loss: 1.516398
# (Epoch 8 / 20) train loss: 1.283393; val loss: 1.484315
# (Epoch 9 / 20) train loss: 1.245546; val loss: 1.487446
# (Epoch 10 / 20) train loss: 1.210522; val loss: 1.495647
# (Epoch 11 / 20) train loss: 1.169109; val loss: 1.484535
# (Epoch 12 / 20) train loss: 1.142872; val loss: 1.490336
# (Epoch 13 / 20) train loss: 1.119380; val loss: 1.504711
# Stopping early at epoch 12!
#
# Evaluating Config #3 [of 10]:
#  {'learning_rate': 0.0007995255879026633, 'reg': 9.884350669094562e-06, 'loss_func': <exercise_code.networks.loss.CrossEntropyFromLogits object at 0x000001EF198D74E0>, 'activation': <exercise_code.networks.layer.LeakyRelu object at 0x000001EF199BC7B8>}
# (Epoch 1 / 20) train loss: 2.302625; val loss: 2.302627
# (Epoch 2 / 20) train loss: 1.831541; val loss: 1.677877
# (Epoch 3 / 20) train loss: 1.584431; val loss: 1.575408
# (Epoch 4 / 20) train loss: 1.482753; val loss: 1.532384
# (Epoch 5 / 20) train loss: 1.410807; val loss: 1.499202
# (Epoch 6 / 20) train loss: 1.352421; val loss: 1.471673
# (Epoch 7 / 20) train loss: 1.300034; val loss: 1.481898
# (Epoch 8 / 20) train loss: 1.256544; val loss: 1.493001
# (Epoch 9 / 20) train loss: 1.214121; val loss: 1.494195
# (Epoch 10 / 20) train loss: 1.171528; val loss: 1.478207
# (Epoch 11 / 20) train loss: 1.136771; val loss: 1.491033
# Stopping early at epoch 10!
#
# Evaluating Config #4 [of 10]:
#  {'learning_rate': 0.0007707436525246034, 'reg': 5.743189022333249e-06, 'loss_func': <exercise_code.networks.loss.CrossEntropyFromLogits object at 0x000001EF198D74E0>, 'activation': <exercise_code.networks.layer.LeakyRelu object at 0x000001EF199BC7B8>}
# (Epoch 1 / 20) train loss: 2.302616; val loss: 2.302615
# (Epoch 2 / 20) train loss: 1.845145; val loss: 1.685587
# (Epoch 3 / 20) train loss: 1.593427; val loss: 1.582208
# (Epoch 4 / 20) train loss: 1.484890; val loss: 1.532834
# (Epoch 5 / 20) train loss: 1.410378; val loss: 1.501236
# (Epoch 6 / 20) train loss: 1.352207; val loss: 1.493348
# (Epoch 7 / 20) train loss: 1.304584; val loss: 1.482188
# (Epoch 8 / 20) train loss: 1.256098; val loss: 1.479668
# (Epoch 9 / 20) train loss: 1.221166; val loss: 1.471728
# (Epoch 10 / 20) train loss: 1.181215; val loss: 1.473165
# (Epoch 11 / 20) train loss: 1.149661; val loss: 1.505187
# (Epoch 12 / 20) train loss: 1.112143; val loss: 1.494406
# (Epoch 13 / 20) train loss: 1.083126; val loss: 1.501752
# (Epoch 14 / 20) train loss: 1.053303; val loss: 1.511571
# Stopping early at epoch 13!
#
# Evaluating Config #5 [of 10]:
#  {'learning_rate': 0.0007540445394229753, 'reg': 7.43725852910078e-07, 'loss_func': <exercise_code.networks.loss.CrossEntropyFromLogits object at 0x000001EF198D74E0>, 'activation': <exercise_code.networks.layer.LeakyRelu object at 0x000001EF199BC7B8>}
# (Epoch 1 / 20) train loss: 2.302621; val loss: 2.302623
# (Epoch 2 / 20) train loss: 1.839257; val loss: 1.678350
# (Epoch 3 / 20) train loss: 1.591772; val loss: 1.586897
# (Epoch 4 / 20) train loss: 1.486370; val loss: 1.535597
# (Epoch 5 / 20) train loss: 1.411041; val loss: 1.522240
# (Epoch 6 / 20) train loss: 1.354371; val loss: 1.492639
# (Epoch 7 / 20) train loss: 1.306784; val loss: 1.484301
# (Epoch 8 / 20) train loss: 1.261391; val loss: 1.484363
# (Epoch 9 / 20) train loss: 1.224128; val loss: 1.489770
# (Epoch 10 / 20) train loss: 1.184415; val loss: 1.491078
# (Epoch 11 / 20) train loss: 1.146500; val loss: 1.485709
# (Epoch 12 / 20) train loss: 1.121996; val loss: 1.504985
# Stopping early at epoch 11!
#
# Evaluating Config #6 [of 10]:
#  {'learning_rate': 0.0008388358143153771, 'reg': 9.124594512099771e-06, 'loss_func': <exercise_code.networks.loss.CrossEntropyFromLogits object at 0x000001EF198D74E0>, 'activation': <exercise_code.networks.layer.LeakyRelu object at 0x000001EF199BC7B8>}
# (Epoch 1 / 20) train loss: 2.302613; val loss: 2.302609
# (Epoch 2 / 20) train loss: 1.829321; val loss: 1.671733
# (Epoch 3 / 20) train loss: 1.585946; val loss: 1.589957
# (Epoch 4 / 20) train loss: 1.486498; val loss: 1.541744
# (Epoch 5 / 20) train loss: 1.413908; val loss: 1.521069
# (Epoch 6 / 20) train loss: 1.358530; val loss: 1.498258
# (Epoch 7 / 20) train loss: 1.306139; val loss: 1.480775
# (Epoch 8 / 20) train loss: 1.263567; val loss: 1.484730
# (Epoch 9 / 20) train loss: 1.218265; val loss: 1.498769
# (Epoch 10 / 20) train loss: 1.182117; val loss: 1.482704
# (Epoch 11 / 20) train loss: 1.146439; val loss: 1.523808
# (Epoch 12 / 20) train loss: 1.116767; val loss: 1.494184
# Stopping early at epoch 11!
#
# Evaluating Config #7 [of 10]:
#  {'learning_rate': 0.0006247823688615057, 'reg': 6.6880495444380155e-06, 'loss_func': <exercise_code.networks.loss.CrossEntropyFromLogits object at 0x000001EF198D74E0>, 'activation': <exercise_code.networks.layer.LeakyRelu object at 0x000001EF199BC7B8>}
# (Epoch 1 / 20) train loss: 2.302589; val loss: 2.302585
# (Epoch 2 / 20) train loss: 1.857201; val loss: 1.692570
# (Epoch 3 / 20) train loss: 1.609159; val loss: 1.604062
# (Epoch 4 / 20) train loss: 1.512602; val loss: 1.547678
# (Epoch 5 / 20) train loss: 1.442004; val loss: 1.526779
# (Epoch 6 / 20) train loss: 1.387955; val loss: 1.508387
# (Epoch 7 / 20) train loss: 1.346685; val loss: 1.498311
# (Epoch 8 / 20) train loss: 1.296293; val loss: 1.488174
# (Epoch 9 / 20) train loss: 1.261351; val loss: 1.499680
# (Epoch 10 / 20) train loss: 1.228867; val loss: 1.482305
# (Epoch 11 / 20) train loss: 1.196420; val loss: 1.491631
# (Epoch 12 / 20) train loss: 1.159757; val loss: 1.489648
# (Epoch 13 / 20) train loss: 1.134291; val loss: 1.482647
# (Epoch 14 / 20) train loss: 1.100894; val loss: 1.500083
# (Epoch 15 / 20) train loss: 1.081965; val loss: 1.498369
# Stopping early at epoch 14!
#
# Evaluating Config #8 [of 10]:
#  {'learning_rate': 0.0007663570921653018, 'reg': 7.916412392380407e-06, 'loss_func': <exercise_code.networks.loss.CrossEntropyFromLogits object at 0x000001EF198D74E0>, 'activation': <exercise_code.networks.layer.LeakyRelu object at 0x000001EF199BC7B8>}
# (Epoch 1 / 20) train loss: 2.302621; val loss: 2.302620
# (Epoch 2 / 20) train loss: 1.843065; val loss: 1.679407
# (Epoch 3 / 20) train loss: 1.595600; val loss: 1.613052
# (Epoch 4 / 20) train loss: 1.488924; val loss: 1.540520
# (Epoch 5 / 20) train loss: 1.415795; val loss: 1.505685
# (Epoch 6 / 20) train loss: 1.361037; val loss: 1.495124
# (Epoch 7 / 20) train loss: 1.306775; val loss: 1.486178
# (Epoch 8 / 20) train loss: 1.262342; val loss: 1.477247
# (Epoch 9 / 20) train loss: 1.228380; val loss: 1.480463
# (Epoch 10 / 20) train loss: 1.191000; val loss: 1.501362
# (Epoch 11 / 20) train loss: 1.155460; val loss: 1.489871
# (Epoch 12 / 20) train loss: 1.125967; val loss: 1.499502
# (Epoch 13 / 20) train loss: 1.093501; val loss: 1.498710
# Stopping early at epoch 12!
#
# Evaluating Config #9 [of 10]:
#  {'learning_rate': 0.0007031655537621403, 'reg': 6.203541343614402e-06, 'loss_func': <exercise_code.networks.loss.CrossEntropyFromLogits object at 0x000001EF198D74E0>, 'activation': <exercise_code.networks.layer.LeakyRelu object at 0x000001EF199BC7B8>}
# (Epoch 1 / 20) train loss: 2.302574; val loss: 2.302577
# (Epoch 2 / 20) train loss: 1.851221; val loss: 1.686116
# (Epoch 3 / 20) train loss: 1.599244; val loss: 1.584338
# (Epoch 4 / 20) train loss: 1.494871; val loss: 1.536736
# (Epoch 5 / 20) train loss: 1.428216; val loss: 1.519071
# (Epoch 6 / 20) train loss: 1.371093; val loss: 1.493657
# (Epoch 7 / 20) train loss: 1.319910; val loss: 1.495767
# (Epoch 8 / 20) train loss: 1.274732; val loss: 1.501313
# (Epoch 9 / 20) train loss: 1.239472; val loss: 1.484119
# (Epoch 10 / 20) train loss: 1.199115; val loss: 1.479959
# (Epoch 11 / 20) train loss: 1.165678; val loss: 1.486820
# (Epoch 12 / 20) train loss: 1.135682; val loss: 1.491956
# (Epoch 13 / 20) train loss: 1.105550; val loss: 1.487435
# (Epoch 14 / 20) train loss: 1.071206; val loss: 1.499852
# (Epoch 15 / 20) train loss: 1.046875; val loss: 1.497716
# Stopping early at epoch 14!
#
# Evaluating Config #10 [of 10]:
#  {'learning_rate': 0.0008925740598203574, 'reg': 9.47453891477425e-06, 'loss_func': <exercise_code.networks.loss.CrossEntropyFromLogits object at 0x000001EF198D74E0>, 'activation': <exercise_code.networks.layer.LeakyRelu object at 0x000001EF199BC7B8>}
# (Epoch 1 / 20) train loss: 2.302583; val loss: 2.302584
# (Epoch 2 / 20) train loss: 1.825006; val loss: 1.663745
# (Epoch 3 / 20) train loss: 1.569768; val loss: 1.583432
# (Epoch 4 / 20) train loss: 1.472966; val loss: 1.519532
# (Epoch 5 / 20) train loss: 1.399939; val loss: 1.504680
# (Epoch 6 / 20) train loss: 1.344118; val loss: 1.493624
# (Epoch 7 / 20) train loss: 1.285022; val loss: 1.482130
# (Epoch 8 / 20) train loss: 1.251300; val loss: 1.486464
# (Epoch 9 / 20) train loss: 1.210306; val loss: 1.508402
# (Epoch 10 / 20) train loss: 1.175291; val loss: 1.496560
# (Epoch 11 / 20) train loss: 1.131967; val loss: 1.513706
# (Epoch 12 / 20) train loss: 1.097563; val loss: 1.502533
# Stopping early at epoch 11!
#
# Search done. Best Val Loss = 1.460792703757307
# Best Config: {'learning_rate': 0.0005566921237071903, 'reg': 6.891715848497006e-06, 'loss_func': <exercise_code.networks.loss.CrossEntropyFromLogits object at 0x000001EF198D74E0>, 'activation': <exercise_code.networks.layer.LeakyRelu object at 0x000001EF199BC7B8>}

# %% [markdown]
# Now it's time to edit the ranges above and adjust them to explore regions that performed well!
#
# Also, feel free to experiment around! Also the network architecture, optimizer options and activations functions, etc. are hyperparameters that you can change!
#
# Try to get your accuracy as high as possible! That's all what counts for this submission!
#
# You'll pass if you reach at least **48%** accuracy on our test set - but there will also be a leaderboard of all students of this course. Will you make it to the top?

# %% [markdown]
# ## Checking the validation accuracy

# %%
labels, pred, acc = best_model.get_dataset_prediction(dataloaders['train'])
print("Train Accuracy: {}%".format(acc*100))
labels, pred, acc = best_model.get_dataset_prediction(dataloaders['val'])
print("Validation Accuracy: {}%".format(acc*100))
# Out:
# Train Accuracy: 65.38127670940172%
# Validation Accuracy: 50.01001602564102%

# %% [markdown]
# # Test your model
# When you have finished your hyperparameter tuning and are sure you have your final model that performs well on the validation set (**you should at least get 48% accuracy on the validation set!**), it's time to run your  model on the test set.
#
# <div class="alert alert-danger">
#     <h3>Important</h3>
#     <p>As you have learned in the lecture, you must only use the test set one single time! So only run the next cell if you are really sure your model works well enough and that you want to submit. Your test set is different from the test set on our server, so results may vary. Nevertheless, you will have a reasonable close approximation about your performance if you only do a final evaluation on the test set.</p>
#     <p>If you are an external student that can't use our submission webpage: this test performance is your final result and if you surpassed the threshold, you have completed this exercise :). Now, train again to aim for a better number!</p>
# </div>

# %%
# comment this part out to see your model's performance on the test set.

labels, pred, acc = best_model.get_dataset_prediction(dataloaders['test'])
print("Test Accuracy: {}%".format(acc*100))
# Out:
# Test Accuracy: 49.84975961538461%

# %% [markdown]
# Note: The "real" test set is actually the dataset we're using for testing your model, which is **different** from the test-set you're using here.

# %% [markdown]
# # Saving your Model

# %%
from exercise_code.tests import save_pickle
save_pickle({"cifar_fcn": best_model}, "cifar_fcn_1.p")

# %% [markdown]
# # Submission Instructions
#
# Congratulations! You've just built your first image classifier! To complete the exercise, submit your final model to our submission portal - you probably know the procedure by now.
#
# 1. Go on [our submission page](https://dvl.in.tum.de/teaching/submission/), register for an account and login. We use your matriculation number and send an email with the login details to the mail account associated. When in doubt, login into tum online and check your mails there. You will get an id which we need in the next step.
# 2. Navigate to `exercise_code` directory and run the `create_submission.sh` file to create the zip file of your model. This will create a single `zip` file that you need to upload. Otherwise, you can also zip it manually if you don't want to use the bash script.
# 3. Log into [our submission page](https://dvl.in.tum.de/teaching/submission/) with your account details and upload the `zip` file. Once successfully uploaded, you should be able to see the submitted "dummy_model.p" file selectable on the top.
# 4. Click on this file and run the submission script. You will get an email with your score as well as a message if you have surpassed the threshold.
#
# # Submission Goals
#
# - Goal: Successfully implement a fully connected NN image classifier, tune hyperparameters.
#
# - Passing Criteria: This time, there are no unit tests that check specific components of your code. The only thing that's required to pass the submission, is your model to reach at least **48% accuracy** on __our__ test dataset. The submission system will show you a number between 0 and 100 which corresponds to your accuracy.
#
# - Submission start: __May 28, 2020 12.00__
# - Submission deadline : __June 03, 2020 23.59__
# - You can make **$\infty$** submissions until the deadline. Your __best submission__ will be considered for bonus
